# %% [markdown]
# # [Project Euler 12](https://projecteuler.net/problem=12)
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be ```1 + 2 + 3 + 4 + 5 + 6 + 7 = 28```. The first ten terms would be:
#
# ```1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...```
#
# Let us list the factors of the first seven triangle numbers:
#
# ``` 1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
# 28: 1,2,4,7,14,28 ```
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
import math

def divisor_count_1(n):
    count = 2
    d = 2
    while d <= math.sqrt(n):
        if n % d == 0:
            count += 2
        if 
        d += 1
    return count

#testing
divisor_count(28)
# Out:
# 6

# %%
#Counts divisors of n by finding divisors of successive quotients of n.
def divisor_count_2(n):
    c = 2 #Divisor count, which come in pairs.
    q = n #Quotient.
    d=2 #Test divisor. 
    while d**2 <= q:
        if q % d == 0:
            c += 2
            q = q // d
            d = 2
        else: 
            d += 1
    return c

#Test
divisor_count_2(28)
# Out:
# 6

# %%
t = 1 #First triagnular number
counter = 2 #Used to get next triagnular number. 

while divisor_count_1(t) < 500:
    t = t + counter
    count += 1
    
    
print(t)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-8b7295806fb9> in <module>
#       2 counter = 2 #Used to get next triagnular number.
#       3
# ----> 4 while divisor_count_1(t) < 500:
#       5     t = t + counter
#       6     count += 1
#
# <ipython-input-20-39d5dc80a4b0> in divisor_count_1(n)
#       7         if n % d == 0:
#       8             count += 2
# ----> 9         d += 1
#      10     return count
#      11
#
# KeyboardInterrupt:

# %%
def divisors(n):
    number_of_factors = 0
    for i in range(1, int(math.ceil(math.sqrt(n)))+1):
        if n % i == 0:
            number_of_factors +=2
        if i*i==n:
            number_of_factors -=1
    return number_of_factors

x=1
for y in range(2,1000000):
    x += y
    if divisors(x) >= 500:
        print(x)
        break
# Out:
# 76576500
